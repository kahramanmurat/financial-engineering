# %%
import pandas as pd

# %%
df=pd.read_csv('sp500sub.csv',index_col='Date',parse_dates=True)

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2010-01-04  33.139999  33.639999  32.889999  33.630001  19.328218  5130400
# 2010-01-05  33.650002  33.750000  33.430000  33.599998  19.310978  6568700
# 2010-01-06  33.630001  33.740002  33.169998  33.419998  19.207529  2972700
# 2010-01-07  33.290001  33.389999  32.880001  32.970001  18.948900  1923800
# 2010-01-08  32.790001  33.009998  32.619999  32.880001  18.897175  1764000
#
#            Name
# Date
# 2010-01-04  PEG
# 2010-01-05  PEG
# 2010-01-06  PEG
# 2010-01-07  PEG
# 2010-01-08  PEG

# %%
goog=df[df['Name']=='GOOG']

# %%
goog[['Close','Adj Close']].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>

# %%
aapl=df[df['Name']=='AAPL']
aapl[['Close','Adj Close']].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>
